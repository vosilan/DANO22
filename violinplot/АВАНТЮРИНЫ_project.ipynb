# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_excel('АВАНТЮРИНЫ_variety.xlsx')
df.head()
# Out:
#          id  happiness variety
# 0  10208740        0.0     low
# 1  10213906        0.0     low
# 2  10214579        0.0     low
# 3  10215339        0.0     low
# 4  10215898        0.0     low

# %%
sns.violinplot(x='variety',y='happiness',data=df)
plt.show()

# %%
df = pd.read_excel('АВАНТЮРИНЫ_activity.xlsx')
df.head()
# Out:
#          id  happiness activity
# 0  10277050        0.0      low
# 1  10294295        0.0      low
# 2  10308889        0.0      low
# 3  10320578        0.0      low
# 4  10336194        0.0      low

# %%
sns.violinplot(x='activity',y='happiness',data=df)
plt.show()
